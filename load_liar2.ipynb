# %%
import pandas as pd

DATA_DIR = "liar2"

train_data = pd.read_csv(f"{DATA_DIR}/train.csv")
valid_data = pd.read_csv(f"{DATA_DIR}/valid.csv")
test_data = pd.read_csv(f"{DATA_DIR}/test.csv")

# %%
from IPython.display import display
display(train_data.head())
# Out:
#       id  label                                          statement              date                                            subject  \
# 0  13847      5  90 percent of Americans "support universal bac...   October 2, 2017  government regulation;polls and public opinion...
# 1  13411      1  Last year was one of the deadliest years ever ...      May 19, 2017  after the fact;congress;criminal justice;histo...
# 2  10882      0  Bernie Sanders's plan is "to raise your taxes ...  October 28, 2015                                              taxes
# 3  20697      4  Voter ID is supported by an overwhelming major...  December 8, 2021                                      voter id laws
# 4   6095      2  Says Barack Obama "robbed Medicare (of) $716 b...   August 12, 2012         federal budget;history;medicare;retirement
#
#           speaker                                speaker_description      state_info  true_counts  mostly_true_counts  half_true_counts  \
# 0     chris abele  Chris Abele is Milwaukee County Executive, a p...       wisconsin            1                   4                 5
# 1     thom tillis  Thom Tillis is a Republican who serves as U.S....  north carolina            0                   2                 7
# 2  chris christie  Chris Christie announced June 6, 2023 that he ...        national           21                  20                27
# 3      lee zeldin  Lee Zeldin is a Republican representing New Yo...        new york            1                   2                 0
# 4     mitt romney  Mitt Romney is a U.S. senator from Utah. He ra...        national           31                  33                58
#
#    mostly_false_counts  false_counts  pants_on_fire_counts                                            context  \
# 0                    3             5                     2                                            a tweet
# 1                    3             2                     0  a press release supporting the Back The Blue A...
# 2                   11            17                     8                                      Boulder, Colo
# 3                    0             0                     0                                            a Tweet
# 4                   35            32                    19                       an interview on "60 Minutes"
#
#                                        justification
# 0  "Universal" is the term for background checks ...
# 1  Sen. Thom Tillis, a North Carolina Republican,...
# 2  Christie said that Sanders’s plan is "to raise...
# 3  Zeldin claimed voter identification requiremen...
# 4  Romney said, "There's only one president that ...

# %%
display(pd.DataFrame({"column": train_data.columns}))
# Out:
#                   column
# 0                     id
# 1                  label
# 2              statement
# 3                   date
# 4                subject
# 5                speaker
# 6    speaker_description
# 7             state_info
# 8            true_counts
# 9     mostly_true_counts
# 10      half_true_counts
# 11   mostly_false_counts
# 12          false_counts
# 13  pants_on_fire_counts
# 14               context
# 15         justification

# %%
display(pd.DataFrame({
    "split": ["train", "validation", "test"],
    "rows": [train_data.shape[0], valid_data.shape[0], test_data.shape[0]],
    "columns": [train_data.shape[1], valid_data.shape[1], test_data.shape[1]],
}))
# Out:
#         split   rows  columns
# 0       train  18369       16
# 1  validation   2297       16
# 2        test   2296       16

# %%
print("Train shape:", train_data.shape)
print("Validation shape:", valid_data.shape)
print("Test shape:", test_data.shape)
# Out:
# Train shape: (18369, 16)
# Validation shape: (2297, 16)
# Test shape: (2296, 16)
